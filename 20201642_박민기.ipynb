# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# 1) 웹페이지 접근해서 정보를 가져와야함 => response 객체 => html 페이지

url = 'http://www.yes24.com/Main/default.aspx'
res = requests.get(url)
html_str = res.text
print(res)

# 2) 뷰티풀 숩 객체화
# html 페이지 => 숩객체

soup = BeautifulSoup(html_str)
# soup

# 3) 소스 파악
# 크롬개발자 모드 : f12 , ctrl+shift+i

# 4) 순위 정보 추출
# tp02 클래스 값을 가지고 있는 li 태그

 # 리스트로 받는다
target = soup.select('li.tp02')

 # tp02의 갯수가 10개
print(len(target))
print(target[0]) # 1위의 tp
print()
print(target[-1]) # 10위의 tp
print()

# 5) 1위에서 개별 정보 추출
# 순위, 책제목, 저자, 출판사

print('순위 → ', target[0].select_one('strong').text)
print('책 제목 → ', target[0].select('strong')[1].text)
print('저자 → ', target[0].select('em')[1].text)
print('출판사 → ', target[0].select_one('a')['title'].split()[-1])

# 6) 2차원 리스트 구조로 변경

# 빈리스트 생성
bestbook_list = []
for a in target:
    순위 = a.select_one('strong').text
    책제목 = a.select('strong')[1].text
    저자 = a.select('em')[1].text
    출판사 = a.select_one('a')['title'].split()[-1]

    print(순위, 책제목, 저자, 출판사)

    # 리스트에 추가
    bestbook_list.append([순위, 책제목, 저자, 출판사])

    # 데이터프레임
pd.DataFrame(bestbook_list, columns=['순위', '책제목', '저자', '출판사'])
df = pd.DataFrame(bestbook_list, columns=['순위', '책제목', '저자', '출판사'])
df
# Out:
# <Response [200]>
# 10
# <li class="tp02">
# <strong class="icon rnk_1">1위</strong>
# <em class="rnk_chg chg_even">0</em>
# <span class="rnk_img"><img alt="유지만 다이어트 레시피" border="0" src="https://image.yes24.com/Goods/146723664/S" width="40"/></span>
# <span class="rnk_info">
# <strong>유지만 다이어트 레시피</strong>
# <em>유지만 저</em>
# </span>
# <a class="rnk_lnk" href="/Product/Goods/146723664" onclick="setWcode('010_006');" target="_self" title="유지만 다이어트 레시피 유지만 저 길벗">'유지만 다이어트 레시피' 상품상세로 이동</a>
# </li>
#
# <li class="tp02">
# <strong class="icon rnk_10">10위</strong>
# <em class="rnk_chg chg_dn">4</em>
# <span class="rnk_img"><img alt="어른의 품격을 채우는 100일 필사 노트" border="0" src="https://image.yes24.com/Goods/142687238/S" width="40"/></span>
# <span class="rnk_info">
# <strong>어른의 품격을 채우는 100일 필사 노트</strong>
# <em>김종원 저</em>
# </span>
# <a class="rnk_lnk" href="/Product/Goods/142687238" onclick="setWcode('010_006');" target="_self" title="어른의 품격을 채우는 100일 필사 노트 김종원 저 청림Life">'어른의 품격을 채우는 100일 필사 노트' 상품상세로 이동</a>
# </li>
#
# 순위 →  1위
# 책 제목 →  유지만 다이어트 레시피
# 저자 →  유지만 저
# 출판사 →  길벗
# 1위 유지만 다이어트 레시피 유지만 저 길벗
# 2위 청춘의 독서 유시민 저 웅진지식하우스
# 3위 혼모노 성해나 저 창비
# 4위 우리의 낙원에서 만나자 하태완 저 북로망스
# 5위 왓츠 유어 드림 사이먼 스큅 저/최인하 역 북파머스
# 6위 멜로우TV 3 : 멜싹오싹 위험한 미션 멜로우TV 원저/한바리 글/차차 그림 학산문화사(단행본)
# 7위 첫 여름, 완주 김금희 저 무제
# 8위 결국 국민이 합니다 이재명 저 오마이북
# 9위 단 한 번의 삶 김영하 저 복복서가
# 10위 어른의 품격을 채우는 100일 필사 노트 김종원 저 청림Life
#     순위                     책제목                    저자         출판사
# 0   1위            유지만 다이어트 레시피                 유지만 저          길벗
# 1   2위                  청춘의 독서                 유시민 저     웅진지식하우스
# 2   3위                     혼모노                 성해나 저          창비
# 3   4위            우리의 낙원에서 만나자                 하태완 저        북로망스
# 4   5위                왓츠 유어 드림        사이먼 스큅 저/최인하 역        북파머스
# 5   6위   멜로우TV 3 : 멜싹오싹 위험한 미션  멜로우TV 원저/한바리 글/차차 그림  학산문화사(단행본)
# 6   7위                첫 여름, 완주                 김금희 저          무제
# 7   8위              결국 국민이 합니다                 이재명 저        오마이북
# 8   9위                단 한 번의 삶                 김영하 저        복복서가
# 9  10위  어른의 품격을 채우는 100일 필사 노트                 김종원 저      청림Life
